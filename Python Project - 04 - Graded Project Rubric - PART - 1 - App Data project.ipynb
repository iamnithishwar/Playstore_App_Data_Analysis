# %% [markdown]
# # PART - 1

# %% [markdown]
# # Scoring guide (Rubric) - Python Project - 04 - Graded Project Rubric

# %% [markdown]
# # EDA & Data Preprocessing on Google App Store Rating Dataset.
#
# # Domain: Mobile device apps
#
# # Context: The Play Store apps data has enormous potential to drive app-making businesses to success. However, many apps are being developed every single day and only a few of them become profitable. It is important for developers to be able to predict the success of their app and incorporate features which makes an app successful. Before any such predictive-study can be done, it is necessary to do EDA and data-preprocessing on the apps data available for google app store applications. From the collected apps data and user ratings from the app stores, let's try to extract insightful information.
#
# # Objective: The Goal is to explore the data and pre-process it for future use in any predictive analytics study.
#
# # Data set Information: Web scraped data of 10k Play Store apps for analyzing the Android market. Each app (row) has values for category, rating, size, and more.

# %% [markdown]
# # 1. Import required libraries and read the dataset. (2 marks)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Nithish\Desktop\GL\Python\week 4\week 4 Graded project\Datasets\Apps_data+(1).csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features. (2 marks)

# %%
df.head(10)  #---First few samples
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
df.shape #---This dataframe has 10841 rows and 13 columns
# Out:
# (10841, 13)

# %%
df.info()    #---By using info() function, i got to know that this df has 12 object columns and one float columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.columns   #---This dataframe has various type of features(columns), will analyze each and everything
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# # 3. Check summary statistics of the dataset. List out the columns that need to be worked upon for model building. (2 marks)

# %%
df.describe()   #-- Since rating dtype is float, describe() function only applied to this column
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df['Rating'].skew()
# Out:
# 0.5956367473804342

# %%
df['Rating'].kurt()
# Out:
# 65.99478130826435

# %%
df['Rating'].corr
# Out:
# <bound method Series.corr of 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64>

# %%
# --These columns are need to be worked upon for model building.

catcols = df.select_dtypes(include='O')
catcols
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # 4. Check if there are any duplicate records in the dataset? if any drop them. (2 marks)

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
10841 - 483 #--(duplicated columns before dropping)
# Out:
# 10358

# %%
#---Dropping duplicate values

df.drop_duplicates(inplace=True)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # 5. Check the unique categories of the column 'Category', Is there any invalid category? If yes, drop them. (2 marks)

# %%
len(df['Category'].unique())  #--length of the category column
# Out:
# 34

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df['Category'].value_counts()  #---checking before dropping the invalid category(1.9)
# Out:
# Category
# FAMILY                 1943
# GAME                   1121
# TOOLS                   843
# BUSINESS                427
# MEDICAL                 408
# PRODUCTIVITY            407
# PERSONALIZATION         388
# LIFESTYLE               373
# COMMUNICATION           366
# FINANCE                 360
# SPORTS                  351
# PHOTOGRAPHY             322
# HEALTH_AND_FITNESS      306
# SOCIAL                  280
# NEWS_AND_MAGAZINES      264
# TRAVEL_AND_LOCAL        237
# BOOKS_AND_REFERENCE     230
# SHOPPING                224
# DATING                  196
# VIDEO_PLAYERS           175
# MAPS_AND_NAVIGATION     137
# EDUCATION               130
# FOOD_AND_DRINK          124
# ENTERTAINMENT           111
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# HOUSE_AND_HOME           80
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
df['Category'][df['Category'] == '1.9']    #--pull the index of 1.9
# Out:
# 10472    1.9
# Name: Category, dtype: object

# %%
#---Another method to pull index of specific values

# --df.iloc(10472)

# %%
df['Category'] = df['Category'].drop(index=10472)   #---Dropping the invalid category(1.9)
df['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10358, dtype: object

# %%
df             #---df after dropping 1.9-invalid category
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Category'].value_counts()  #---checking after dropping the invalid category(1.9)
# Out:
# Category
# FAMILY                 1943
# GAME                   1121
# TOOLS                   843
# BUSINESS                427
# MEDICAL                 408
# PRODUCTIVITY            407
# PERSONALIZATION         388
# LIFESTYLE               373
# COMMUNICATION           366
# FINANCE                 360
# SPORTS                  351
# PHOTOGRAPHY             322
# HEALTH_AND_FITNESS      306
# SOCIAL                  280
# NEWS_AND_MAGAZINES      264
# TRAVEL_AND_LOCAL        237
# BOOKS_AND_REFERENCE     230
# SHOPPING                224
# DATING                  196
# VIDEO_PLAYERS           175
# MAPS_AND_NAVIGATION     137
# EDUCATION               130
# FOOD_AND_DRINK          124
# ENTERTAINMENT           111
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# HOUSE_AND_HOME           80
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
df['Category'].isnull().sum()
# Out:
# 1

# %%
df['Category'].mode()[0]
# Out:
# 'FAMILY'

# %%
df['Category'] = df['Category'].fillna(df['Category'].mode()[0])
df['Category']
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10358, dtype: object

# %% [markdown]
# # 6. Check if there are missing values present in the column Rating, If any? drop them and and create a new column as 'Rating_category' by converting ratings to high and low categories(>3.5 is high rest low) (3 marks)

# %%
df['Rating'].isnull().sum()     #---Checking before removing null values
# Out:
# 1465

# %%
df = df.dropna(subset='Rating')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Rating'].isnull().sum()   #---Checking after removing null values
# Out:
# 0

# %%
df['Rating_category'] = df['Rating'].apply(lambda x:'High' if x>3.5 else 'Low')
df['Rating_category']
# Out:
# C:\Users\Nithish\AppData\Local\Temp\ipykernel_12012\87577131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rating_category'] = df['Rating'].apply(lambda x:'High' if x>3.5 else 'Low')
# 0        High
# 1        High
# 2        High
# 3        High
# 4        High
#          ...
# 10834    High
# 10836    High
# 10837    High
# 10839    High
# 10840    High
# Name: Rating_category, Length: 8893, dtype: object

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Rating_category'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # 7. Check the distribution of the newly created column 'Rating_category' and comment on the distribution. (2 marks)

# %%
# --- To pull the distribution of Rating_category column

Rating_category_Distribution = df['Rating_category'].value_counts()
Rating_category_Distribution
# Out:
# Rating_category
# High    8013
# Low      880
# Name: count, dtype: int64

# %%
#---Distribution of 'Rating_category' using pie chart


plt.figure(figsize=(5,3))
plt.pie(df['Rating_category'].value_counts(),labels=df['Rating_category'].value_counts().index, autopct='%1.1f%%', shadow=True)
plt.title('distribution of Rating_category')
plt.show()

# %% [markdown]
# #  8. Convert the column "Reviews'' to numeric data type and check the presence of outliers in the column and handle the outliers using a transformation approach.(Hint: Use log transformation) (2 marks)

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df['Reviews'].dtypes
# Out:
# dtype('O')

# %%
df['Reviews'] =  pd.to_numeric(df['Reviews'], errors='coerce') 
df['Reviews']
# Out:
# C:\Users\Nithish\AppData\Local\Temp\ipykernel_12012\676789892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Reviews'] =  pd.to_numeric(df['Reviews'], errors='coerce')
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10834         7.0
# 10836        38.0
# 10837         4.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews, Length: 8893, dtype: float64

# %%
# Check for the presence of outliers using box plot in 'Reviews' column

plt.figure(figsize=(5,2))
sns.boxplot(data=df, y=df['Reviews'])
plt.show()

# %%
# Handle outliers using log transformation

df['reviews'] = np.log(df['Reviews'])   # --Log transformation to supress the outliers
df['reviews']
# Out:
# C:\Users\Nithish\AppData\Local\Temp\ipykernel_12012\2382583333.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reviews'] = np.log(df['Reviews'])   # --Log transformation to supress the outliers
# 0         5.068904
# 1         6.874198
# 2        11.379508
# 3        12.281384
# 4         6.874198
#            ...
# 10834     1.945910
# 10836     3.637586
# 10837     1.386294
# 10839     4.736198
# 10840    12.894978
# Name: reviews, Length: 8893, dtype: float64

# %%
sns.boxplot(df['reviews'])  #---Checking if Reviews column has outliers or not after supress the outliers
# Out:
# <Axes: >

# %%
df = df.drop(columns='Reviews')   #---Dropping Reviews column from df

# %%
df    #---Checking if Reviews column dropped or not
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['reviews'].isnull().sum()  #---checking null values of newly created reviews column
# Out:
# 1

# %%
df['reviews'].mean()     #---pull mean value
# Out:
# 8.234892597330452

# %%
df['reviews'].median()   #---pull median values
# Out:
# 8.458397689368425

# %%
df['reviews'].mode()[0]  #--pull mode values
# Out:
# 0.6931471805599453

# %%
df['reviews'] = df['reviews'].fillna(df['reviews'].mode()[0])
df['reviews']

#---fill the nan using mode values
# Out:
# 0         5.068904
# 1         6.874198
# 2        11.379508
# 3        12.281384
# 4         6.874198
#            ...
# 10834     1.945910
# 10836     3.637586
# 10837     1.386294
# 10839     4.736198
# 10840    12.894978
# Name: reviews, Length: 8893, dtype: float64

# %%
df['reviews'].isnull().sum()    #---Now, nan is zero
# Out:
# 0

# %% [markdown]
# # 9. The column 'Size' contains alphanumeric values, treat the non numeric data and convert the column into suitable data type. (hint: Replace M with 1 million and K with 1 thousand, and drop the entries where size='Varies with device') (3 marks)

# %%
df['Size'].dtypes    #---Checking dtype
# Out:
# dtype('O')

# %%
df['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10834                  2.6M
# 10836                   53M
# 10837                  3.6M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 8893, dtype: object

# %%
df['Size'] = df['Size'].str.replace('M', '000000')
df['Size'] = df['Size'].str.replace('k', '000')


#---Replacing M with 000000 and K with 000

# %%
df['Size'].sample(15)    #---Checking that all the k and M got changed or not
# Out:
# 5962               32000000
# 4599               19000000
# 7466               38000000
# 9779               17000000
# 5535               91000000
# 4582                 314000
# 4803              5.0000000
# 2759     Varies with device
# 5849     Varies with device
# 6661     Varies with device
# 4744     Varies with device
# 8279               11000000
# 10011              82000000
# 1358               24000000
# 5778     Varies with device
# Name: Size, dtype: object

# %%
df['Size'][df['Size'] == 'Varies with device']     #---Checking if 'Varies with device' is present or not
# Out:
# 37       Varies with device
# 42       Varies with device
# 52       Varies with device
# 67       Varies with device
# 68       Varies with device
#                 ...
# 10713    Varies with device
# 10725    Varies with device
# 10765    Varies with device
# 10826    Varies with device
# 10839    Varies with device
# Name: Size, Length: 1468, dtype: object

# %%
len(df['Size'][df['Size'] == 'Varies with device'])   #---len of 'Varies with device'
# Out:
# 1468

# %%
len(df)
# Out:
# 8893

# %%
8893 - 1468
# Out:
# 7425

# %%
df['changed_size'] = df['Size'][df['Size'] != 'Varies with device']
df['changed_size']


#---Pull all the values except 'Varies with device' from 'changed_size' column
# Out:
# 0         19000000
# 1         14000000
# 2        8.7000000
# 3         25000000
# 4        2.8000000
#            ...
# 10834    2.6000000
# 10836     53000000
# 10837    3.6000000
# 10839          NaN
# 10840     19000000
# Name: changed_size, Length: 8893, dtype: object

# %%
df['changed_size'].dtypes   #---Checking dtypes
# Out:
# dtype('O')

# %%
df['changed_size'] = df['changed_size'].str.replace(',','')
df['changed_size']

#---Replace , with empty
# Out:
# 0         19000000
# 1         14000000
# 2        8.7000000
# 3         25000000
# 4        2.8000000
#            ...
# 10834    2.6000000
# 10836     53000000
# 10837    3.6000000
# 10839          NaN
# 10840     19000000
# Name: changed_size, Length: 8893, dtype: object

# %%
df['changed_size'] = df['changed_size'].str.replace('+','')
df['changed_size']

#---Replace + with empty
# Out:
# 0         19000000
# 1         14000000
# 2        8.7000000
# 3         25000000
# 4        2.8000000
#            ...
# 10834    2.6000000
# 10836     53000000
# 10837    3.6000000
# 10839          NaN
# 10840     19000000
# Name: changed_size, Length: 8893, dtype: object

# %%
df['changed_size'] = df['changed_size'].str.replace('.','')
df['changed_size']

#---Replace . with empty
# Out:
# 0        19000000
# 1        14000000
# 2        87000000
# 3        25000000
# 4        28000000
#            ...
# 10834    26000000
# 10836    53000000
# 10837    36000000
# 10839         NaN
# 10840    19000000
# Name: changed_size, Length: 8893, dtype: object

# %%
df['changed_size'].isnull().sum()
# Out:
# 1468

# %%
df['changed_size'] = df['changed_size'].fillna(0)
df['changed_size']
# Out:
# 0        19000000
# 1        14000000
# 2        87000000
# 3        25000000
# 4        28000000
#            ...
# 10834    26000000
# 10836    53000000
# 10837    36000000
# 10839           0
# 10840    19000000
# Name: changed_size, Length: 8893, dtype: object

# %%
df['changed_size'] = df['changed_size'].astype(int)
df['changed_size']

#---Converting changed_size column to int
# Out:
# 0        19000000
# 1        14000000
# 2        87000000
# 3        25000000
# 4        28000000
#            ...
# 10834    26000000
# 10836    53000000
# 10837    36000000
# 10839           0
# 10840    19000000
# Name: changed_size, Length: 8893, dtype: int32

# %%
df = df.drop(columns='Size')   #--Dropping Size column

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # 10. Check the column 'Installs', treat the unwanted characters and convert the column into a suitable data type. (2 marks)

# %%
df['Installs']   #---Pull values of installs
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10834           500+
# 10836         5,000+
# 10837           100+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 8893, dtype: object

# %%
df['Installs'].value_counts()   #---Checking the counts of values
# Out:
# Installs
# 1,000,000+        1486
# 10,000,000+       1132
# 100,000+          1110
# 10,000+            989
# 1,000+             698
# 5,000,000+         683
# 500,000+           516
# 50,000+            462
# 5,000+             426
# 100,000,000+       369
# 100+               303
# 50,000,000+        272
# 500+               199
# 10+                 69
# 500,000,000+        61
# 50+                 56
# 1,000,000,000+      49
# 5+                   9
# 1+                   3
# Free                 1
# Name: count, dtype: int64

# %%
df['Installs'].unique()   #---Pull unique values
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '100+', '500+', '10+',
#        '5+', '50+', '1+', 'Free'], dtype=object)

# %%
df['Installs'] = df['Installs'].str.replace(',', '')
df['Installs'] = df['Installs'].str.replace('+', '')

#---Replace , with empty
#---Replace + with empty

# %%
df['Installs'][df['Installs'] == 'Free']     #---Checking if 'Free' is present or not
# Out:
# 10472    Free
# Name: Installs, dtype: object

# %%
df['Installs'] = df['Installs'].drop(index= 10472)
df['Installs']

#---Dropping the specific index value
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10834         500
# 10836        5000
# 10837         100
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 8893, dtype: object

# %%
df['Installs'].dtypes   #---Checking dtypes
# Out:
# dtype('O')

# %%
df['Installs'].isnull().sum()   #----Checking null values
# Out:
# 1

# %%
df['Installs'] = df['Installs'].fillna(0)
df['Installs']


#---Fill all the null values
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10834         500
# 10836        5000
# 10837         100
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 8893, dtype: object

# %%
df['Installs'].isnull().sum()
# Out:
# 0

# %%
df['Installs'] = df['Installs'].astype(int)
df['Installs']

#---Changing dtypes
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10834         500
# 10836        5000
# 10837         100
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 8893, dtype: int32

# %% [markdown]
# # 11. Check the column 'Price' , remove the unwanted characters and convert the column into a suitable data type. (2 marks)

# %%
df['Price']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10834    0
# 10836    0
# 10837    0
# 10839    0
# 10840    0
# Name: Price, Length: 8893, dtype: object

# %%
df['Price'].value_counts()
# Out:
# Price
# 0          8279
# $2.99       110
# $0.99       105
# $4.99        68
# $1.99        59
#            ...
# $1.29         1
# $299.99       1
# $379.99       1
# $37.99        1
# $1.20         1
# Name: count, Length: 74, dtype: int64

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$7.99', '$5.99', '$2.99', '$3.49',
#        '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00',
#        '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$29.99',
#        '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99',
#        '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$1.49', '$3.88',
#        '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77',
#        '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$8.49', '$1.75', '$14.00', '$2.00',
#        '$3.08', '$2.59', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04',
#        '$13.99', '$4.29', '$3.28', '$4.60', '$1.00', '$2.95', '$2.90',
#        '$1.97', '$2.56', 'Everyone', '$1.20'], dtype=object)

# %%
df['Price'] = df['Price'].str.replace('$','')
df['Price'] = df['Price'].str.replace('.','')

#---Replace $ with empty
#---Replace . with empty

# %%
df['Price'][df['Price'] == 'Everyone']        #---Checking if 'Everyone' is present or not
# Out:
# 10472    Everyone
# Name: Price, dtype: object

# %%
df['Price'] = df['Price'].drop(index=10472)
df['Price']

#---Dropping the specific index value
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10834    0
# 10836    0
# 10837    0
# 10839    0
# 10840    0
# Name: Price, Length: 8893, dtype: object

# %%
df['Price'].isnull().sum()   #----Checking null values
# Out:
# 1

# %%
df['Price'] = df['Price'].fillna(0)
df['Price']

#---Fill all the null values
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10834    0
# 10836    0
# 10837    0
# 10839    0
# 10840    0
# Name: Price, Length: 8893, dtype: object

# %%
df['Price'].isnull().sum()
# Out:
# 0

# %%
df['Price'] = df['Price'].astype(int)
df['Price']

#---Changing dtypes
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10834    0
# 10836    0
# 10837    0
# 10839    0
# 10840    0
# Name: Price, Length: 8893, dtype: int32

# %% [markdown]
# # Handling 'Content Rating' column

# %%
df['Content Rating'].isnull().sum()  #---Checking null values
# Out:
# 1

# %%
df['Content Rating'].mode()[0]       #--pull mode value
# Out:
# 'Everyone'

# %%
df['Content Rating'] = df['Content Rating'].fillna(df['Content Rating'].mode()[0])
df['Content Rating']

#---Fill all the null values
# Out:
# 0          Everyone
# 1          Everyone
# 2          Everyone
# 3              Teen
# 4          Everyone
#             ...
# 10834      Everyone
# 10836      Everyone
# 10837      Everyone
# 10839    Mature 17+
# 10840      Everyone
# Name: Content Rating, Length: 8893, dtype: object

# %%
df['Content Rating'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Handling 'App' column

# %%
df['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Fr. Mike Schmitz Audio Teachings',
#        'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %% [markdown]
# # Handling 'Type' column

# %%
df['Type'][df['Type'] == '0']            #---Checking if '0' is present or not
# Out:
# 10472    0
# Name: Type, dtype: object

# %%
df['Type'] = df['Type'].drop(index=10472)
df['Type']

#---Dropping the specific index value
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10834    Free
# 10836    Free
# 10837    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 8893, dtype: object

# %%
df['Type'] = df['Type'].str.replace('0','Free')
df['Type']

#---Replacing 0 with free
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10834    Free
# 10836    Free
# 10837    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 8893, dtype: object

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
df['Type'].isnull().sum()    #---Checking null values
# Out:
# 1

# %%
df['Type'].mode()[0]         #--Pull mode value
# Out:
# 'Free'

# %%
df['Type'] = df['Type'].fillna(df['Type'].mode()[0])
df['Type']

#--Fill all the null values
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10834    Free
# 10836    Free
# 10837    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 8893, dtype: object

# %%
df['Type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Handling 'Genres' column

# %%
df['Genres'].unique()   #---Pull unique values
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Auto & Vehicles', 'Beauty',
#        'Books & Reference', 'Business', 'Comics', 'Comics;Creativity',
#        'Communication', 'Dating', 'Education;Education', 'Education',
#        'Education;Creativity', 'Education;Music & Video',
#        'Education;Action & Adventure', 'Education;Pretend Play',
#        'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
#        'Casual;Action & Adventure', 'Simulation', 'Adventure', 'Board',
# ...

# %% [markdown]
# # 12. Drop the columns which you think redundant for the analysis.(suggestion: drop column 'rating', since we created a new feature from it (i.e. rating_category) and the columns 'App', 'Rating' ,'Genres','Last Updated', 'Current Ver','Android Ver' columns since which are redundant for our analysis) (2 marks)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df = df.drop(columns=['Rating', 'Last Updated', 'Current Ver', 'Android Ver'])

#---Dropping all the redundant columns to do the proper analysis

# %%
df  #---Checking if all the columns are dropped or not
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# #  13. Encode the categorical columns. (2 marks)

# %%
catcols = df.select_dtypes(include='O').columns
catcols

#---Pull all the categorical columns
# Out:
# Index(['App', 'Category', 'Type', 'Content Rating', 'Genres',
#        'Rating_category'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

#---Importing LabelEncoder from sklearn - preprocessing

# %%
df['App'] = le.fit_transform(df['App'])
df['App']

#--fit and transform the values in App column
# Out:
# 0        5809
# 1        2134
# 2        7326
# 3        6577
# 4        5865
#          ...
# 10834    3410
# 10836    6896
# 10837    3701
# 10839    7099
# 10840    8049
# Name: App, Length: 8893, dtype: int64

# %%
df['Category'] = le.fit_transform(df['Category'])
df['Category']

#--fit and transform the values in category column
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 10834    11
# 10836    11
# 10837    11
# 10839     3
# 10840    18
# Name: Category, Length: 8893, dtype: int64

# %%
df['Type'] = le.fit_transform(df['Type'])
df['Type']

#--fit and transform the values in Type column
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10834    0
# 10836    0
# 10837    0
# 10839    0
# 10840    0
# Name: Type, Length: 8893, dtype: int32

# %%
df['Content Rating'] = le.fit_transform(df['Content Rating'])
df['Content Rating']

#--fit and transform the values in content Rating column
# Out:
# 0        1
# 1        1
# 2        1
# 3        4
# 4        1
#         ..
# 10834    1
# 10836    1
# 10837    1
# 10839    3
# 10840    1
# Name: Content Rating, Length: 8893, dtype: int32

# %%
df['Genres'] = le.fit_transform(df['Genres'])
df['Genres']

#--fit and transform the values in Genres column
# Out:
# 0         9
# 1        11
# 2         9
# 3         9
# 4        10
#          ..
# 10834    37
# 10836    37
# 10837    37
# 10839    18
# 10840    66
# Name: Genres, Length: 8893, dtype: int32

# %%
df['Rating_category'] = le.fit_transform(df['Rating_category'])
df['Rating_category']

#--fit and transform the values in Rating_category column
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10834    0
# 10836    0
# 10837    0
# 10839    0
# 10840    0
# Name: Rating_category, Length: 8893, dtype: int32

# %%
df  #---Checking if all the columns are got transformed or not in df
# Out:
#         App  Category  Installs  Type  Price  Content Rating  Genres  \
# 0      5809         0     10000     0      0               1       9
# 1      2134         0    500000     0      0               1      11
# 2      7326         0   5000000     0      0               1       9
# 3      6577         0  50000000     0      0               4       9
# 4      5865         0    100000     0      0               1      10
# ...     ...       ...       ...   ...    ...             ...     ...
# 10834  3410        11       500     0      0               1      37
# 10836  6896        11      5000     0      0               1      37
# 10837  3701        11       100     0      0               1      37
# 10839  7099         3      1000     0      0               3      18
# 10840  8049        18  10000000     0      0               1      66
#
#        Rating_category    reviews  changed_size
# 0                    0   5.068904      19000000
# ...

# %%
df.dtypes   #---Checking dtypes
# Out:
# App                  int64
# Category             int64
# Installs             int32
# Type                 int32
# Price                int32
# Content Rating       int32
# Genres               int32
# Rating_category      int32
# reviews            float64
# changed_size         int32
# dtype: object

# %% [markdown]
# # 14. Segregate the target and independent features (Hint: Use Rating_category as the target) (2 marks)

# %%
independent_features_x = df.drop(columns='Rating_category')
target_y = df[['Rating_category']]

#----Segregating the target(y) and independent features(x)

# %%
independent_features_x
# Out:
#         App  Category  Installs  Type  Price  Content Rating  Genres  \
# 0      5809         0     10000     0      0               1       9
# 1      2134         0    500000     0      0               1      11
# 2      7326         0   5000000     0      0               1       9
# 3      6577         0  50000000     0      0               4       9
# 4      5865         0    100000     0      0               1      10
# ...     ...       ...       ...   ...    ...             ...     ...
# 10834  3410        11       500     0      0               1      37
# 10836  6896        11      5000     0      0               1      37
# 10837  3701        11       100     0      0               1      37
# 10839  7099         3      1000     0      0               3      18
# 10840  8049        18  10000000     0      0               1      66
#
#          reviews  changed_size
# 0       5.068904      19000000
# 1       6.874198      14000000
# 2      11.379508      87000000
# ...

# %%
target_y
# Out:
#        Rating_category
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 10834                0
# 10836                0
# 10837                0
# 10839                0
# 10840                0
#
# [8893 rows x 1 columns]

# %% [markdown]
# # 15. Split the dataset into train and test. (2 marks)

# %%
from sklearn.model_selection import train_test_split

#---Importing train_test_split from sklearn - model_selection

# %%
x_train, x_test, y_train, y_test = train_test_split(independent_features_x,target_y, test_size=0.25, random_state=555)


#----Spliting as x_train, x_test, y_train, y_test

# %%
x_train
# Out:
#        App  Category  Installs  Type  Price  Content Rating  Genres  \
# 3651  7624        32    100000     0      0               1     114
# 4928   133        21   1000000     0      0               2      74
# 9734  2608        11    100000     0      0               1      95
# 168   8004         3   1000000     0      0               1      18
# 922    839         9   1000000     0      0               4      50
# ...    ...       ...       ...   ...    ...             ...     ...
# 8638  2698        14   5000000     0      0               1      87
# 247   2229         4    500000     0      0               1      20
# 8026  4153        11    500000     0      0               1      50
# 9088  6796        14  10000000     0      0               4       0
# 5552  6822        11     10000     0      0               4      50
#
#         reviews  changed_size
# 3651   7.669962             0
# 4928  10.055822      14000000
# 9734   7.855545      53000000
# ...

# %%
x_test
# Out:
#        App  Category  Installs  Type  Price  Content Rating  Genres  \
# 4014  4711        11     10000     0      0               1      37
# 4932   137        16    100000     0      0               1      64
# 4950   416        29   1000000     0      0               1     106
# 8064  1801        29       500     0      0               1     106
# 4107  7486        29  50000000     0      0               4     106
# ...    ...       ...       ...   ...    ...             ...     ...
# 6207  4710        11     50000     0      0               1      37
# 7415  7074        14   1000000     0      0               4       0
# 9601  7756        14  10000000     0      0               4      21
# 8432  7034        14  10000000     0      0               4      24
# 6087  1171        14  10000000     0      0               2       0
#
#         reviews  changed_size
# 4014   3.761200      37000000
# 4932   7.279319      97000000
# 4950   9.581283      43000000
# ...

# %%
y_train
# Out:
#       Rating_category
# 3651                0
# 4928                0
# 9734                1
# 168                 0
# 922                 0
# ...               ...
# 8638                0
# 247                 0
# 8026                0
# 9088                0
# 5552                0
#
# [6669 rows x 1 columns]

# %%
y_test
# Out:
#       Rating_category
# 4014                0
# 4932                1
# 4950                0
# 8064                0
# 4107                0
# ...               ...
# 6207                0
# 7415                0
# 9601                0
# 8432                0
# 6087                0
#
# [2224 rows x 1 columns]

# %% [markdown]
# # 16. Standardize the data, so that the values are within a particular range. (2 marks)

# %%
from sklearn.preprocessing import StandardScaler

#---Importing StandardScaler from sklearn - preprocessing

# %%
ss = StandardScaler()

# %%
df = ss.fit_transform(df)    #--fit and transform the values in df

# %%
df = pd.DataFrame(df)

# %%
df   #---Checking if all the columns are got transformed or not in df
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.708736 -2.033208 -0.190789 -0.272092 -0.059493 -0.469985 -1.635118
# 1    -0.846927 -2.033208 -0.185116 -0.272092 -0.059493 -0.469985 -1.574482
# 2     1.350897 -2.033208 -0.133012 -0.272092 -0.059493 -0.469985 -1.635118
# 3     1.033838 -2.033208  0.388023 -0.272092 -0.059493  2.481001 -1.635118
# 4     0.732441 -2.033208 -0.189747 -0.272092 -0.059493 -0.469985 -1.604800
# ...        ...       ...       ...       ...       ...       ...       ...
# 8888 -0.306784 -0.704090 -0.190899 -0.272092 -0.059493 -0.469985 -0.786217
# 8889  1.168874 -0.704090 -0.190847 -0.272092 -0.059493 -0.469985 -0.786217
# 8890 -0.183601 -0.704090 -0.190904 -0.272092 -0.059493 -0.469985 -0.786217
# 8891  1.254806 -1.670721 -0.190893 -0.272092 -0.059493  1.497339 -1.362257
# 8892  1.656950  0.141712 -0.075119 -0.272092 -0.059493 -0.469985  0.093003
#
#              7         8         9
# ...
